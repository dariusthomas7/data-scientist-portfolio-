# %%
import pandas as pd

# %%
import openpyxl

# %%
babies = pd.read_excel("/Users/ortegap1/Desktop/SCI Data/DS 104 Data Rangling VIZ/babies.xlsx")

# %% [markdown]
# pip install openpyxl

# %%
babies.head()
# Out:
#        Name        First   Birthday                 StreetAddress      City  \
# 0    Potter      Alec J. 2017-11-06      229-8390 Dignissim. Road  Ucluelet
# 1   Mcclure    Lucius S. 2018-08-14   P.O. Box 593, 7892 Nunc St.  Licantén
# 2    Farley     Hilel Y. 2017-12-07               3859 Tellus Rd.      Alva
# 3  Cummings   Randall W. 2018-03-07  Ap #293-6684 Lobortis Street    Vicuña
# 4    Lester     Bruce I. 2018-01-14           495-3192 Dictum St.   Bonnert
#
#    Zipcode  Weight  Height     HospitalID ParentPhoneNumber  \
# 0    36170       1       9  1672053023999    1-180-978-6309
# 1    47279       5      19  1609023064699    1-667-136-7396
# 2    78490       6       5  1664012354399    1-914-735-7605
# 3    36395       9       9  1669072896099    1-568-861-3669
# 4    25130      10      15  1603101020999    1-494-905-3888
#
#                         ParentEmail Footprint
# 0                  ut@nisiAenean.ca       Yes
# 1         Donec.luctus@Maecenas.edu       Yes
# ...

# %%
## python .function after data set name

# %%
babies['Footprint']='Yes'

# %%
fake = pd.read_excel("/Users/ortegap1/Desktop/SCI Data/DS 104 Data Rangling VIZ/FakeNews.xlsx")

# %%
fake.head()
# Out:
#               when                                                url  \
# 0  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 1  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 2  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 3  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 4  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker Storytype
# 0                     DoubleClick      FAKE
# 1                      RevContent      FAKE
# 2                     DoubleClick      FAKE
# 3              Google Syndication      FAKE
# 4  DoubleClick Ad Exchange-Seller      FAKE

# %%
fake['Storytype']='FAKE'

# %%
fake.drop(['when'],axis=1) # axis=1 is for columns axis=0 is for rows 
# ([''])
# Out:
#                                                     url  \
# 0     http://wayback.archive.org/web/20161004072420i...
# 1     http://wayback.archive.org/web/20161004072420i...
# 2     http://wayback.archive.org/web/20161004072420i...
# 3     http://wayback.archive.org/web/20161004072420i...
# 4     http://wayback.archive.org/web/20161004072420i...
# ...                                                 ...
# 3334  https://www.ncscooper.com/transgender-dog-unsu...
# 3335  https://www.ncscooper.com/transgender-dog-unsu...
# 3336  https://www.ncscooper.com/transgender-dog-unsu...
# 3337  https://www.ncscooper.com/transgender-dog-unsu...
# 3338  https://www.ncscooper.com/transgender-dog-unsu...
#
#                              tracker Storytype
# 0                        DoubleClick      FAKE
# 1                         RevContent      FAKE
# 2                        DoubleClick      FAKE
# 3                 Google Syndication      FAKE
# 4     DoubleClick Ad Exchange-Seller      FAKE
# ...

# %%
fake1 = fake['url'].str.split('_', expand=True).rename(columns = lambda x: "URL"+str(x+1))
fake1.head()

fake2 = pd.concat([fake, fake1], axis=1)
fake2.head()

fake2.drop(['url'], axis=1, inplace=True)
fake2.head()

#Put back together the domain column

fake2['url'] = fake2["URL1"] + "_" + fake2["URL2"].map(str)
fake2.head()

fake2.drop(['URL1', 'URL2'], axis=1, inplace=True)
fake2.head()

#Keep only the first ten rows of the data
fake3 = fake2[:10]
fake3
# Out:
#               when                         tracker Storytype  \
# 0  before-nov-2016                     DoubleClick      FAKE
# 1  before-nov-2016                      RevContent      FAKE
# 2  before-nov-2016                     DoubleClick      FAKE
# 3  before-nov-2016              Google Syndication      FAKE
# 4  before-nov-2016  DoubleClick Ad Exchange-Seller      FAKE
# 5  before-nov-2016                           Kixer      FAKE
# 6  before-nov-2016                  Google Adsense      FAKE
# 7  before-nov-2016                     DoubleClick      FAKE
# 8  before-nov-2016                     DoubleClick      FAKE
# 9  before-nov-2016              Google Syndication      FAKE
#
#                                                  url
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# ...
